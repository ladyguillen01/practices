# %%
import pandas as pd
import webbrowser as web
import pyautogui as pg
import time

# %%
import webbrowser as web

# %%
# Cargar el archivo Excel
data = pd.read_excel("CSO.xlsx")
# Mostrar las primeras filas
data.head(3)
# Out:
#                FECHAF      fecha     RAZON CLIENTE CENTRO DE COSTO TIPO  \
# 0 2025-03-19 23:00:00 2025-03-19  estimada   SANNA     CALL MEDICO  TDP
# 1 2025-03-19 23:00:00 2025-03-19  estimada   SANNA     CALL MEDICO  TDP
# 2 2025-03-19 23:00:00 2025-03-19  estimada   SANNA     CALL MEDICO  TDP
#
#                 LIDER       SEDE                NOMBRE DEL PERSONAL  \
# 0  CAROLINA GUTIERREZ  SURQUILLO            JIMENEZ TORNERO, XIMENA
# 1  CAROLINA GUTIERREZ  SURQUILLO              AYLAS LLUNGO BRIGITTE
# 2  CAROLINA GUTIERREZ  SURQUILLO  CAMPOS MEDINA, ESTEFANI ALEJANDRA
#
#     TELEFONO  ... DISTRITO RECOJO                 DIREECION DESTINO  \
# 0  961033228  ...       SURQUILLO  AV PABLO CARRIQUIRRI 366 DPT 202
# 1  933862505  ...       SURQUILLO          HOSPITAL SERGIO BERNALES
# 2  980685073  ...       SURQUILLO  JR. PIETRO TORIGIANO 467 DPT 202
#
#   REFERENCIAS.1 DISTRITO DE DESTINO          CONDUCTOR SANNA PERSONAL  \
# 0           NaN          SAN ISIDRO         JUAN MANTA  15.0      NaN
# 1           NaN               COMAS  GALINDO ALEJANDRO  34.0      NaN
# 2           NaN           SAN BORJA         JUAN MANTA  15.0      NaN
#
#   NOTA OPERATIVA OBSERVACION  \
# 0     CONFIRMADO         NaN
# 1     CONFIRMADO         NaN
# 2     CONFIRMADO         NaN
#
#                                                DATOS
# 0  CONDUCTOR                                     ...
# 1  CONDUCTOR                                     ...
# 2  CONDUCTOR                                     ...
#
# [3 rows x 24 columns]

# %%
data = pd.read_excel("CSO.xlsx")

# Iterar sobre los números de teléfono
for i in range(len(data)):
    celular = str(data.loc[i, 'TELEFONO'])  # Convertir a string
    nombre = data.loc[i,'NOMBRE DEL PERSONAL']
    servicio=data.loc[i,'SERVICIO']
    drecojo =data.loc[i,'DISTRITO RECOJO']
    ddestino =data.loc[i,'DISTRITO DE DESTINO']
    datos= data.loc[i,'DATOS']
    razon= data.loc[i,'RAZON']
    fecha= str(data.loc[i,'FECHAF'])
    
    mensaje = "Buenas👋 " + razon+ " " + nombre + ", su servicio de traslado de " + servicio +" programada para "+ fecha +" hrs,  desde " + drecojo + " a " + ddestino+ " tiene como conductor asignado al                                                                                                                               🚗" + datos
        # Ruta de Google Chrome (ajústala según tu sistema)
    chrome_path = "C:\\Program Files\\Google\\Chrome\\Application\\chrome.exe"

    # Registrar el navegador
    web.register("chrome", None, web.BackgroundBrowser(chrome_path))

    # Abrir WhatsApp Web en Chrome
    web.get("chrome").open(f"https://web.whatsapp.com/send?phone={celular}&text={mensaje}")

    time.sleep(18)
    pg.click(1230,946)
    pg.press('enter')  
    time.sleep(5)  
    pg.click(1053,261)
    pg.hotkey('ctrl', 'w')
    pg.press('enter')  
    time.sleep(2)

# %% [raw]
# TDP

# %%
# Cargar el archivo Excel
tdp = pd.read_excel("TDP.xlsx")
# Mostrar las primeras filas
tdp.head(3)
